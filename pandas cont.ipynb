# %% [markdown]
# # Day Agenda
# - reading the different format of data sets
# - statistical information about data sets
# - concatination of data frames
# - grouping of data frames
# - merging the data frames
# - filtering data from data frames
# -

# %% [markdown]
# ## Reading the different format of data sets
# - csv(comma seerated values)
# - json
# - xlsx
# - tsb(tab seperated values)

# %%
import pandas as pd
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_lib',
#  '_libs',
# ...

# %%
df=pd.read_json("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Data-Science-Using-Python-Internship-EB1/main/Notebooks/Day23-Pandas%20continue/cafes.json")
df
# Out:
#                           alias  \
# 0    coffee-project-ny-new-york
# 1     lella-alimentari-brooklyn
# 2     saltwater-coffee-new-york
# 3       urban-backyard-new-york
# 4      bird-and-branch-new-york
# ..                          ...
# 95     lēna-coffee-bar-new-york
# 96     optimistic-cafe-new-york
# 97         black-brick-brooklyn
# 98             usagi-ny-dumbo-7
# 99  spreadhouse-cafe-new-york-3
#
#                                            categories  coordinates_latitude  \
# 0      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]             40.726990
# 1   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...             40.715160
# 2      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]             40.730458
# 3      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]             40.720770
# 4   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...             40.760310
# ..                                                ...                   ...
# ...

# %%
pd.read_json("dbms.json") # name of local file
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-d63649e1abdb> in <module>
# ----> 1 pd.read_json("dbms.json") # name of local file
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
#     610         filepath_or_buffer.close()
#
# ...

# %% [markdown]
# # convert json to csv data set
# df.to_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Data-Science-Using-Python-Internship-EB1/main/Notebooks/Day23-Pandas%20continue/cafes.json")

# %% [markdown]
# import pandas as pd
# d3=pd.concat((d1,d2),ignore_index=True)
# d3## d1 and d2 are data frames

# %% [markdown]
# d3=pd.concat((d1,d2),keys=['k1','k2'])
# d3

# %% [markdown]
# ## Grouping of dataframes
# - df.groupby

# %% [markdown]
# - g1=d1.groupby(by='clg') *splitting a specific object
# - gi.max()

# %%
df1=pd.DataFrame({"city":['x','y','z'],
                 'temp':[11,12,23],
                 'hum':[44,55,67]})
df1
# Out:
#   city  temp  hum
# 0    x    11   44
# 1    y    12   55
# 2    z    23   67

# %%
m1=pd.DataFrame({"city":['x','y','z'],
                 'hum':[44,55,67]})
m1
# Out:
#   city  hum
# 0    x   44
# 1    y   55
# 2    z   67

# %%
m2=pd.DataFrame({"city":['x','y','z'],
                 'temp':[11,12,23]})
m2
# Out:
#   city  temp
# 0    x    11
# 1    y    12
# 2    z    23

# %%
m3=pd.merge(m1,m2)
m3
# Out:
#   city  hum  temp
# 0    x   44    11
# 1    y   55    12
# 2    z   67    23

# %%
m3=pd.merge(m1,m2,on='city',how='left',indicator=True)
m3
# Out:
#   city  hum  temp _merge
# 0    x   44    11   both
# 1    y   55    12   both
# 2    z   67    23   both
