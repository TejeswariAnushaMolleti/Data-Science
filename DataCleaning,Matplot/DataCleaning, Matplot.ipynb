# %% [markdown]
# ### Day Agenda
# - Filtering a Data
# - Sorting a Data Frame
# - Cleaning the Data Frame
# - Matplotlib Introduction
# - Types of Plots

# %% [markdown]
# ## Filtering Data
# - Accessing a particular data or info from given dataframe is called as filtering

# %% [markdown]
# ### 1.Read the data (read_csv)

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Data-Science-Using-Python-Internship-EB1/main/Notebooks/Day23-Pandas%20continue/weather.csv")
df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df.head(3) ## default gives 5 rows as output
# Out:
#    s.no       day  temparature  winspeed event
# 0     1  1/2/2019         30.0      12.0  rain
# 1     1  1/2/2019          NaN      14.0   NaN
# 2     2  1/3/2019         43.0      13.0  rain

# %%
## Rows, Columns
df.shape
# Out:
# (12, 5)

# %%
df.describe()
# Out:
#             s.no  temparature   winspeed
# count  12.000000     8.000000   9.000000
# mean    5.583333    59.000000  13.444444
# std     3.476109    22.940918   3.503966
# min     1.000000    30.000000   9.000000
# 25%     2.750000    40.750000  11.000000
# 50%     5.500000    60.000000  13.000000
# 75%     8.250000    71.750000  15.000000
# max    11.000000    90.000000  20.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   s.no         12 non-null     int64
#  1   day          12 non-null     object
#  2   temparature  8 non-null      float64
#  3   winspeed     9 non-null      float64
#  4   event        9 non-null      object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 608.0+ bytes

# %%
df['temparature']
# Out:
# 0     30.0
# 1      NaN
# 2     43.0
# 3     55.0
# 4     66.0
# 5     34.0
# 6      NaN
# 7     89.0
# 8      NaN
# 9     90.0
# 10    65.0
# 11     NaN
# Name: temparature, dtype: float64

# %%
df['winspeed']
# Out:
# 0     12.0
# 1     14.0
# 2     13.0
# 3      NaN
# 4     10.0
# 5     15.0
# 6     17.0
# 7      NaN
# 8      9.0
# 9     11.0
# 10     NaN
# 11    20.0
# Name: winspeed, dtype: float64

# %%
df['temparature'].count()
# Out:
# 8

# %%
df['temparature'].value_counts() #element counts in a column
# Out:
# 65.0    1
# 90.0    1
# 89.0    1
# 34.0    1
# 66.0    1
# 55.0    1
# 43.0    1
# 30.0    1
# Name: temparature, dtype: int64

# %%
df['temparature']>55
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8     False
# 9      True
# 10     True
# 11    False
# Name: temparature, dtype: bool

# %%
df[df['temparature']>55]
# Out:
#     s.no        day  temparature  winspeed event
# 4      4   1/5/2019         66.0      10.0   NaN
# 7      7   1/8/2019         89.0       NaN  cold
# 9      9  1/10/2019         90.0      11.0  cold
# 10    10  1/11/2019         65.0       NaN   NaN

# %%
df[df['winspeed']>13]
# Out:
#     s.no        day  temparature  winspeed    event
# 1      1   1/2/2019          NaN      14.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df[(df["temparature"]>=30) & (df['winspeed']==15)]
# Out:
#    s.no       day  temparature  winspeed event
# 5     5  1/6/2019         34.0      15.0  cold

# %%
df[(df["temparature"]>=30) | (df['winspeed']==15)]
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 7      7   1/8/2019         89.0       NaN     cold
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN

# %%
df[(df["temparature"]>=40) | (df['winspeed']==15)]
# Out:
#     s.no        day  temparature  winspeed    event
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 7      7   1/8/2019         89.0       NaN     cold
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN

# %% [markdown]
# ## Sorting a data frame
# - ascending order
# - descending order
#     - sort_index
#         - to sort the index of dataset
#      - sort_values
#          - to sort values in side dataset

# %%
df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df.sort_values("temparature")
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 5      5   1/6/2019         34.0      15.0     cold
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 10    10  1/11/2019         65.0       NaN      NaN
# 4      4   1/5/2019         66.0      10.0      NaN
# 7      7   1/8/2019         89.0       NaN     cold
# 9      9  1/10/2019         90.0      11.0     cold
# 1      1   1/2/2019          NaN      14.0      NaN
# 6      6   1/7/2019          NaN      17.0  fullair
# 8      8   1/9/2019          NaN       9.0  fullair
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df.sort_values("temparature",ascending=False)
# Out:
#     s.no        day  temparature  winspeed    event
# 9      9  1/10/2019         90.0      11.0     cold
# 7      7   1/8/2019         89.0       NaN     cold
# 4      4   1/5/2019         66.0      10.0      NaN
# 10    10  1/11/2019         65.0       NaN      NaN
# 3      3   1/4/2019         55.0       NaN  fullair
# 2      2   1/3/2019         43.0      13.0     rain
# 5      5   1/6/2019         34.0      15.0     cold
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 6      6   1/7/2019          NaN      17.0  fullair
# 8      8   1/9/2019          NaN       9.0  fullair
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df.sort_values("temparature",ignore_index=True)
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      5   1/6/2019         34.0      15.0     cold
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4     10  1/11/2019         65.0       NaN      NaN
# 5      4   1/5/2019         66.0      10.0      NaN
# 6      7   1/8/2019         89.0       NaN     cold
# 7      9  1/10/2019         90.0      11.0     cold
# 8      1   1/2/2019          NaN      14.0      NaN
# 9      6   1/7/2019          NaN      17.0  fullair
# 10     8   1/9/2019          NaN       9.0  fullair
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df.sort_values("winspeed")
# Out:
#     s.no        day  temparature  winspeed    event
# 8      8   1/9/2019          NaN       9.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 9      9  1/10/2019         90.0      11.0     cold
# 0      1   1/2/2019         30.0      12.0     rain
# 2      2   1/3/2019         43.0      13.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 11    11  1/12/2019          NaN      20.0  fullair
# 3      3   1/4/2019         55.0       NaN  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 10    10  1/11/2019         65.0       NaN      NaN

# %%
df.sort_index(ascending=False)
# Out:
#     s.no        day  temparature  winspeed    event
# 11    11  1/12/2019          NaN      20.0  fullair
# 10    10  1/11/2019         65.0       NaN      NaN
# 9      9  1/10/2019         90.0      11.0     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 5      5   1/6/2019         34.0      15.0     cold
# 4      4   1/5/2019         66.0      10.0      NaN
# 3      3   1/4/2019         55.0       NaN  fullair
# 2      2   1/3/2019         43.0      13.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 0      1   1/2/2019         30.0      12.0     rain

# %%
df.sort_values(['temparature','winspeed'])
## based on first col i.e., temparature it sorts
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 5      5   1/6/2019         34.0      15.0     cold
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 10    10  1/11/2019         65.0       NaN      NaN
# 4      4   1/5/2019         66.0      10.0      NaN
# 7      7   1/8/2019         89.0       NaN     cold
# 9      9  1/10/2019         90.0      11.0     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 1      1   1/2/2019          NaN      14.0      NaN
# 6      6   1/7/2019          NaN      17.0  fullair
# 11    11  1/12/2019          NaN      20.0  fullair

# %% [markdown]
# ## cleaning the data frame
# - To check unwanted data/missing data
#     - isnull()
#     - notnull()
# - to remove unwanted data
#     -mdrpna()
# - Handling unwanted date
#     - filina()
#     - replace()

# %%
df.head()
# Out:
#    s.no       day  temparature  winspeed    event
# 0     1  1/2/2019         30.0      12.0     rain
# 1     1  1/2/2019          NaN      14.0      NaN
# 2     2  1/3/2019         43.0      13.0     rain
# 3     3  1/4/2019         55.0       NaN  fullair
# 4     4  1/5/2019         66.0      10.0      NaN

# %% [markdown]
# ## preprocessing the data
# - checking the null values
# - remove null values
# - fill null values

# %%
df.isnull()
# Out:
#      s.no    day  temparature  winspeed  event
# 0   False  False        False     False  False
# 1   False  False         True     False   True
# 2   False  False        False     False  False
# 3   False  False        False      True  False
# 4   False  False        False     False   True
# 5   False  False        False     False  False
# 6   False  False         True     False  False
# 7   False  False        False      True  False
# 8   False  False         True     False  False
# 9   False  False        False     False  False
# 10  False  False        False      True   True
# 11  False  False         True     False  False

# %%
df[df.isnull()]
# Out:
#     s.no  day  temparature  winspeed event
# 0    NaN  NaN          NaN       NaN   NaN
# 1    NaN  NaN          NaN       NaN   NaN
# 2    NaN  NaN          NaN       NaN   NaN
# 3    NaN  NaN          NaN       NaN   NaN
# 4    NaN  NaN          NaN       NaN   NaN
# 5    NaN  NaN          NaN       NaN   NaN
# 6    NaN  NaN          NaN       NaN   NaN
# 7    NaN  NaN          NaN       NaN   NaN
# 8    NaN  NaN          NaN       NaN   NaN
# 9    NaN  NaN          NaN       NaN   NaN
# 10   NaN  NaN          NaN       NaN   NaN
# 11   NaN  NaN          NaN       NaN   NaN

# %%
df.isnull().count()
# Out:
# s.no           12
# day            12
# temparature    12
# winspeed       12
# event          12
# dtype: int64

# %%
df.isnull().sum()
# Out:
# s.no           0
# day            0
# temparature    4
# winspeed       3
# event          3
# dtype: int64

# %%
d1=df.dropna() # remove entire row if null value is present
d1
# Out:
#    s.no        day  temparature  winspeed event
# 0     1   1/2/2019         30.0      12.0  rain
# 2     2   1/3/2019         43.0      13.0  rain
# 5     5   1/6/2019         34.0      15.0  cold
# 9     9  1/10/2019         90.0      11.0  cold

# %%
df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
d1.isnull().sum()
# Out:
# s.no           0
# day            0
# temparature    0
# winspeed       0
# event          0
# dtype: int64

# %%
df.isnull().count()
# Out:
# s.no           12
# day            12
# temparature    12
# winspeed       12
# event          12
# dtype: int64

# %%
d1.fillna(0)
# Out:
#    s.no        day  temparature  winspeed event
# 0     1   1/2/2019         30.0      12.0  rain
# 2     2   1/3/2019         43.0      13.0  rain
# 5     5   1/6/2019         34.0      15.0  cold
# 9     9  1/10/2019         90.0      11.0  cold

# %%
d2=df.fillna(0)
d2
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          0.0      14.0        0
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       0.0  fullair
# 4      4   1/5/2019         66.0      10.0        0
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          0.0      17.0  fullair
# 7      7   1/8/2019         89.0       0.0     cold
# 8      8   1/9/2019          0.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       0.0        0
# 11    11  1/12/2019          0.0      20.0  fullair

# %%
d2.isnull().sum()
# Out:
# s.no           0
# day            0
# temparature    0
# winspeed       0
# event          0
# dtype: int64

# %%
df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
d3=df.fillna({'temparature':1,'winspeed':2})
d3
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          1.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       2.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          1.0      17.0  fullair
# 7      7   1/8/2019         89.0       2.0     cold
# 8      8   1/9/2019          1.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       2.0      NaN
# 11    11  1/12/2019          1.0      20.0  fullair

# %%
df.fillna({'temparature':1,'winspeed':2},inplace=True)
df #to change in original data
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          1.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       2.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          1.0      17.0  fullair
# 7      7   1/8/2019         89.0       2.0     cold
# 8      8   1/9/2019          1.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       2.0      NaN
# 11    11  1/12/2019          1.0      20.0  fullair

# %%
df.fillna({'temparature':1,'winspeed':2,'event':'sunny'},inplace=True)
df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          1.0      14.0    sunny
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       2.0  fullair
# 4      4   1/5/2019         66.0      10.0    sunny
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          1.0      17.0  fullair
# 7      7   1/8/2019         89.0       2.0     cold
# 8      8   1/9/2019          1.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       2.0    sunny
# 11    11  1/12/2019          1.0      20.0  fullair

# %%
df.isnull().sum()
# Out:
# s.no           0
# day            0
# temparature    0
# winspeed       0
# event          0
# dtype: int64

# %%
df1=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Data-Science-Using-Python-Internship-EB1/main/Notebooks/Day23-Pandas%20continue/weather.csv")
df1
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
df1['temparature'].mean()
# Out:
# 59.0

# %%
df1['temparature']=df1['temparature'].fillna(df1['temparature'].mean())
df1
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      59.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      59.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      59.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
print(df1['winspeed'].median())
# Out:
# 14.5

# %%
df1['winspeed']=df1['winspeed'].fillna(df1['temparature'].median())
df1
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      59.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      59.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      59.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
df1.fillna(11,limit=2) #first 2 nan values replaced with 2
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019         59.0      14.0       11
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      59.0  fullair
# 4      4   1/5/2019         66.0      10.0       11
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      59.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      59.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
df1.fillna(method='ffill') #the forward values are filled in the nan value
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019         59.0      14.0     rain
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      59.0  fullair
# 4      4   1/5/2019         66.0      10.0  fullair
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      59.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      59.0     cold
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
import numpy as np
print(df1['temparature'][0])
df1['temparature'][0]=np.nan
print(df1['temparature'][0])
df1
# Out:
# nan
# nan
# C:\Users\tejeswari\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019          NaN      12.0     rain
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      59.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      59.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      59.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %% [markdown]
# ### To replace any value
# - replace

# %%
df1.head()
# Out:
#    s.no       day  temparature  winspeed    event
# 0     1  1/2/2019          NaN      12.0     rain
# 1     1  1/2/2019         59.0      14.0      NaN
# 2     2  1/3/2019         43.0      13.0     rain
# 3     3  1/4/2019         55.0      59.0  fullair
# 4     4  1/5/2019         66.0      10.0      NaN

# %%
df1.replace('rain','sunny')
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019          NaN      12.0    sunny
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0    sunny
# 3      3   1/4/2019         55.0      59.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      59.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      59.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
df1.replace(20,25)
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019          NaN      12.0     rain
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      59.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      59.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      59.0      NaN
# 11    11  1/12/2019         59.0      25.0  fullair

# %%
df1.columns
# Out:
# Index(['s.no', 'day', 'temparature', 'winspeed', 'event'], dtype='object')

# %%
df1.plot

# %%
df1['n1']=np.random.randint(1,12,12)
df1
# Out:
#     s.no        day  temparature  winspeed    event  n1
# 0      1   1/2/2019          NaN      12.0     rain   2
# 1      1   1/2/2019         59.0      14.0      NaN   8
# 2      2   1/3/2019         43.0      13.0     rain   8
# 3      3   1/4/2019         55.0      59.0  fullair   8
# 4      4   1/5/2019         66.0      10.0      NaN   1
# 5      5   1/6/2019         34.0      15.0     cold   7
# 6      6   1/7/2019         59.0      17.0  fullair  11
# 7      7   1/8/2019         89.0      59.0     cold   5
# 8      8   1/9/2019         59.0       9.0  fullair  11
# 9      9  1/10/2019         90.0      11.0     cold   3
# 10    10  1/11/2019         65.0      59.0      NaN   1
# 11    11  1/12/2019         59.0      20.0  fullair   6

# %%
df1.drop('n1',axis=1)
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019          NaN      12.0     rain
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      59.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      59.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      59.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
df1
# Out:
#     s.no        day  temparature  winspeed    event  n1
# 0      1   1/2/2019          NaN      12.0     rain   6
# 1      1   1/2/2019         59.0      14.0      NaN   2
# 2      2   1/3/2019         43.0      13.0     rain   4
# 3      3   1/4/2019         55.0      59.0  fullair   8
# 4      4   1/5/2019         66.0      10.0      NaN   7
# 5      5   1/6/2019         34.0      15.0     cold   1
# 6      6   1/7/2019         59.0      17.0  fullair   6
# 7      7   1/8/2019         89.0      59.0     cold   4
# 8      8   1/9/2019         59.0       9.0  fullair   9
# 9      9  1/10/2019         90.0      11.0     cold   2
# 10    10  1/11/2019         65.0      59.0      NaN   2
# 11    11  1/12/2019         59.0      20.0  fullair  10

# %%
df1.drop('n1',axis=1,inplace=True)
df1 #to remove from original data
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019          NaN      12.0     rain
# 1      1   1/2/2019         59.0      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0      59.0  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019         59.0      17.0  fullair
# 7      7   1/8/2019         89.0      59.0     cold
# 8      8   1/9/2019         59.0       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0      59.0      NaN
# 11    11  1/12/2019         59.0      20.0  fullair

# %%
df1['n1']=np.random.randint(1,12,12)
df1
# Out:
#     s.no        day  temparature  winspeed    event  n1
# 0      1   1/2/2019          NaN      12.0     rain  11
# 1      1   1/2/2019         59.0      14.0      NaN   6
# 2      2   1/3/2019         43.0      13.0     rain   4
# 3      3   1/4/2019         55.0      59.0  fullair  10
# 4      4   1/5/2019         66.0      10.0      NaN   4
# 5      5   1/6/2019         34.0      15.0     cold   9
# 6      6   1/7/2019         59.0      17.0  fullair   9
# 7      7   1/8/2019         89.0      59.0     cold   6
# 8      8   1/9/2019         59.0       9.0  fullair   1
# 9      9  1/10/2019         90.0      11.0     cold   7
# 10    10  1/11/2019         65.0      59.0      NaN   7
# 11    11  1/12/2019         59.0      20.0  fullair   3

# %%
df1['event']='e1'
df1
# Out:
#     s.no        day  temparature  winspeed event  n1
# 0      1   1/2/2019          NaN      12.0    e1  11
# 1      1   1/2/2019         59.0      14.0    e1   6
# 2      2   1/3/2019         43.0      13.0    e1   4
# 3      3   1/4/2019         55.0      59.0    e1  10
# 4      4   1/5/2019         66.0      10.0    e1   4
# 5      5   1/6/2019         34.0      15.0    e1   9
# 6      6   1/7/2019         59.0      17.0    e1   9
# 7      7   1/8/2019         89.0      59.0    e1   6
# 8      8   1/9/2019         59.0       9.0    e1   1
# 9      9  1/10/2019         90.0      11.0    e1   7
# 10    10  1/11/2019         65.0      59.0    e1   7
# 11    11  1/12/2019         59.0      20.0    e1   3

# %%
df1.plot()
