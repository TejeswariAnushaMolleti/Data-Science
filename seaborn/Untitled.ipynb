# %% [markdown]
# ## Day Agenda
# - Cubehelix paletter observations using histogram/heat map
# - Different Styles of plots in seaborn
#     - catagorical scatter plots
#         - strip plots
#         - swarm plots
#     - catagorical distributed plots
#         - histogram
#         - box
#         - kde plots
#         - violin plots
#     - estimator plots
#         - bar plot
#         - point plot
#         - count plot
# - joint plot
# - pair plot

# %%
import seaborn as sns
import numpy as np
x=np.random.randint(1,20,10).reshape(2,5)
c=sns.cubehelix_palette(as_cmap=True)
sns.heatmap(x)

# %%
import seaborn as sns
import numpy as np
x=np.random.randint(1,20,10).reshape(2,5)
c=sns.cubehelix_palette(as_cmap=True)
sns.heatmap(x,cmap=c)

# %%
import seaborn as sns
import numpy as np
x=np.random.randint(1,20,10).reshape(2,5)
c=sns.cubehelix_palette()
sns.heatmap(x)

# %%
sns.heatmap(x,annot=True)

# %%
sns.heatmap(x,annot=True,linewidths=3)

# %% [markdown]
# ## Categorical scatter plots
# - strip plots
# - swarm plots

# %% [markdown]
# ## get data sets from seaborn

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# C:\Users\tejeswari\anaconda3\lib\site-packages\seaborn\utils.py:384: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\tejeswari\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
## load the dataset
df=sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['species'].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
df.groupby(by='species').sum()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             250.3        171.4          73.1         12.3
# versicolor         296.8        138.5         213.0         66.3
# virginica          329.4        148.7         277.6        101.3

# %% [markdown]
# ## catplot
#    - sns.catplot()

# %%
sns.catplot(data=df)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.catplot(x='sepal_length',y='petal_length',data=df)

# %%
sns.catplot(x='sepal_length',y='petal_length',data=df,hue='species')

# %%
sns.catplot(x='sepal_length',y='petal_length',data=df,hue='petal_width')

# %%
sns.catplot(x='sepal_length',y='petal_length',data=df,hue='species',kind='box')

# %%
sns.catplot(x='sepal_length',y='species',data=df,kind='box')

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='species',kind='bar')

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='species',kind='bar',palette=['r','g','b'])

# %%
sns.catplot(x='sepal_length',y='species',data=df,kind='bar',palette=['r','g','b'],col='species')

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='species',kind='violin',palette=['r','g','b'])

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='species',palette=['r','g','b'],marker='*')

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='species',kind='boxen',palette=['r','g','b'])

# %%
sns.catplot(x='sepal_length',y='species',data=df,kind='boxen',palette=['r','g','b'])

# %% [markdown]
# ## catagorical distributed plots
# - histogram plots
# - box
# - kde plots
# - violin plots

# %% [markdown]
# ## histogram plots
# - plot univariate or bivariate histograms to show distributions of datasets
# - a histogram is a classic visualization tool that represents the distribution of one  or more variables bby counting the num of obs that fall within discrete bins

# %%
df1=sns.load_dataset("tips")
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.histplot(data=df1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-ede9167efda7> in <module>
# ----> 1 sns.histplot(data=df1)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
sns.histplot(x='total_bill',data=df1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-da2d394b963d> in <module>
# ----> 1 sns.histplot(x='total_bill',data=df1)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
import seaborn as sns
sns.histplot(x='total_bill',data=df1,kde=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-e04dc237cfa5> in <module>
#       1 import seaborn as sns
# ----> 2 sns.histplot(x='total_bill',data=df1,kde=True)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Data-Science-Using-Python-Internship-EB1/main/Notebooks/Day23-Pandas%20continue/weather.csv
# Out:
#   File "<ipython-input-54-b9b39a24d501>", line 1
#     https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Data-Science-Using-Python-Internship-EB1/main/Notebooks/Day23-Pandas%20continue/weather.csv
#            ^
# SyntaxError: invalid syntax
